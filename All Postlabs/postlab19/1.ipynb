# %%
import numpy as np

# %%
def z_transform_unit_step():
    print("Z-transform of unit step u[n]: U(z) = 1 / (1 - z^-1) for |z| > 1")

# %%
def check_system_stability(a):
    pole = a
    print("Pole of the system:", pole)
    if abs(pole) < 1:
        print("System is Stable")
    else:
        print("System is Unstable")

# %%
print("---- Z-Transform of Unit Step ----")
z_transform_unit_step()

print("\n---- Stability Check for System H(z) = 1 / (1 - a z^-1) ----")
a = 0.5
check_system_stability(a)
# Out:
# ---- Z-Transform of Unit Step ----
# Z-transform of unit step u[n]: U(z) = 1 / (1 - z^-1) for |z| > 1
#
# ---- Stability Check for System H(z) = 1 / (1 - a z^-1) ----
# Pole of the system: 0.5
# System is Stable
